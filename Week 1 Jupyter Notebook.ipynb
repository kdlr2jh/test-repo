# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Week 1 Assignment
# by: Katherine DeLaRosa

# %%
s = 3
t = 6
s*t
# Out:
# 18

# %%
import numpy
import pandas
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([4,5,6],[7,2,9])

# %%
plt.scatter([4,1,6],[7,2,9])

# %%
# %matplotlib inline

import traceback
import matplotlib.pyplot as plt

import numpy as np

# %%
# %%time

total = 0
for i in range(100000):
    total += i
# Out:
# CPU times: user 13 ms, sys: 455 µs, total: 13.4 ms
# Wall time: 13.1 ms
